# %%
from pandas import read_csv

df = read_csv('heldout_pepfold_inputs.csv')
print(df)
# Out:
#                 query_id generated_sequence
# 0          heldout_50_k2              GKQDV
# 1          heldout_50_k3          EDQHGRDKN
# 2          heldout_50_k5              TDVLM
# 3          heldout_50_k6              VNDTQ
# 4         heldout_105_k3              GTHIA
# ...                  ...                ...
# 14995  heldout_160451_k6             GHFAHP
# 14996  heldout_160911_k1            DYRTFSM
# 14997  heldout_160911_k2            IPSFTNG
# 14998  heldout_160911_k5             RWVIFH
# 14999  heldout_160911_k6             WMICHP
#
# [15000 rows x 2 columns]

# %%
with open('heldout_pepfold_inputs.fst', 'w') as f:
    for i, row in df.iterrows():
        f.write(f">{row['query_id']}\n{row['generated_sequence']}\n")
