# %%
import MDAnalysis as mda
from MDAnalysis.transformations import unwrap, center_in_box
from MDAnalysis.lib.distances import capped_distance, minimize_vectors
import nglview as nv
import numpy as np
import os
# Out:
# /home/go46vuw/miniconda3/lib/python3.12/site-packages/Bio/Application/__init__.py:39: BiopythonDeprecationWarning: The Bio.Application modules and modules relying on it have been deprecated.
#
# Due to the on going maintenance burden of keeping command line application
# wrappers up to date, we have decided to deprecate and eventually remove these
# modules.
#
# We instead now recommend building your command line and invoking it directly
# with the subprocess module.
#   warnings.warn(
